# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\HomePC\Downloads\5G_energy_consumption_dataset.csv")

# %%
df.isnull().sum()
# Out:
# Time       0
# BS         0
# Energy     0
# load       0
# ESMODE     0
# TXpower    0
# dtype: int64

# %%
df.describe()
# Out:
#              Energy          load        ESMODE       TXpower
# count  92629.000000  92629.000000  92629.000000  92629.000000
# mean      28.138997      0.244705      0.081361      6.765427
# std       13.934645      0.234677      0.382317      0.309929
# min        0.747384      0.000000      0.000000      5.381166
# 25%       18.236173      0.057370      0.000000      6.427504
# 50%       24.065770      0.165550      0.000000      6.875934
# 75%       35.724963      0.363766      0.000000      6.875934
# max      100.000000      0.993957      4.000000      8.375336

# %%
df.head()
# Out:
#               Time   BS     Energy      load  ESMODE   TXpower
# 0  20230101 010000  B_0  64.275037  0.487936     0.0  7.101719
# 1  20230101 020000  B_0  55.904335  0.344468     0.0  7.101719
# 2  20230101 030000  B_0  57.698057  0.193766     0.0  7.101719
# 3  20230101 040000  B_0  55.156951  0.222383     0.0  7.101719
# 4  20230101 050000  B_0  56.053812  0.175436     0.0  7.101719

# %%
df.dtypes
# Out:
# Time        object
# BS          object
# Energy     float64
# load       float64
# ESMODE     float64
# TXpower    float64
# dtype: object

# %%
df.ESMODE.nunique()
# Out:
# 1713

# %%
df.BS.nunique()
# Out:
# 923

# %%
df
# Out:
#                   Time      BS     Energy      load  ESMODE   TXpower
# 0      20230101 010000     B_0  64.275037  0.487936     0.0  7.101719
# 1      20230101 020000     B_0  55.904335  0.344468     0.0  7.101719
# 2      20230101 030000     B_0  57.698057  0.193766     0.0  7.101719
# 3      20230101 040000     B_0  55.156951  0.222383     0.0  7.101719
# 4      20230101 050000     B_0  56.053812  0.175436     0.0  7.101719
# ...                ...     ...        ...       ...     ...       ...
# 92624  20230102 170000  B_1018  14.648729  0.087538     0.0  7.325859
# 92625  20230102 180000  B_1018  14.648729  0.082635     0.0  7.325859
# 92626  20230102 210000  B_1018  13.452915  0.055538     0.0  7.325859
# 92627  20230102 220000  B_1018  13.602392  0.058077     0.0  7.325859
# 92628  20230102 230000  B_1018  13.303438  0.048173     0.0  7.325859
#
# [92629 rows x 6 columns]

# %%
df.hist(figsize = (20, 10))
# Out:
# array([[<Axes: title={'center': 'Energy'}>,
#         <Axes: title={'center': 'load'}>],
#        [<Axes: title={'center': 'ESMODE'}>,
#         <Axes: title={'center': 'TXpower'}>]], dtype=object)

# %%
df.columns
# Out:
# Index(['Time', 'BS', 'Energy', 'load', 'ESMODE', 'TXpower'], dtype='object')

# %%
df.head()
# Out:
#               Time   BS     Energy      load  ESMODE   TXpower
# 0  20230101 010000  B_0  64.275037  0.487936     0.0  7.101719
# 1  20230101 020000  B_0  55.904335  0.344468     0.0  7.101719
# 2  20230101 030000  B_0  57.698057  0.193766     0.0  7.101719
# 3  20230101 040000  B_0  55.156951  0.222383     0.0  7.101719
# 4  20230101 050000  B_0  56.053812  0.175436     0.0  7.101719

# %%
df.Time.nunique()
# Out:
# 168

# %%
df
# Out:
#                   Time      BS     Energy      load  ESMODE   TXpower
# 0      20230101 010000     B_0  64.275037  0.487936     0.0  7.101719
# 1      20230101 020000     B_0  55.904335  0.344468     0.0  7.101719
# 2      20230101 030000     B_0  57.698057  0.193766     0.0  7.101719
# 3      20230101 040000     B_0  55.156951  0.222383     0.0  7.101719
# 4      20230101 050000     B_0  56.053812  0.175436     0.0  7.101719
# ...                ...     ...        ...       ...     ...       ...
# 92624  20230102 170000  B_1018  14.648729  0.087538     0.0  7.325859
# 92625  20230102 180000  B_1018  14.648729  0.082635     0.0  7.325859
# 92626  20230102 210000  B_1018  13.452915  0.055538     0.0  7.325859
# 92627  20230102 220000  B_1018  13.602392  0.058077     0.0  7.325859
# 92628  20230102 230000  B_1018  13.303438  0.048173     0.0  7.325859
#
# [92629 rows x 6 columns]

# %%
df.BS.nunique()
# Out:
# 923

# %%
df.drop(columns = ['Time', 'BS'], inplace = True)

# %%
df.columns
# Out:
# Index(['Energy', 'load', 'ESMODE', 'TXpower'], dtype='object')

# %%
df.dtypes
# Out:
# Energy     float64
# load       float64
# ESMODE     float64
# TXpower    float64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model = LinearRegression()

# %%
y = df.Energy
X = df.drop('Energy', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 34)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.fit(X_test, y_test)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.5528201947902298

# %%
model.score(X_test, y_test)
# Out:
# 0.5463500733555914

# %%
df.head()
# Out:
#               Time   BS     Energy      load  ESMODE   TXpower
# 0  20230101 010000  B_0  64.275037  0.487936     0.0  7.101719
# 1  20230101 020000  B_0  55.904335  0.344468     0.0  7.101719
# 2  20230101 030000  B_0  57.698057  0.193766     0.0  7.101719
# 3  20230101 040000  B_0  55.156951  0.222383     0.0  7.101719
# 4  20230101 050000  B_0  56.053812  0.175436     0.0  7.101719

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop('BS', axis = 1, inplace = True)

# %%
df.head()
# Out:
#               Time     Energy      load  ESMODE   TXpower
# 0  20230101 010000  64.275037  0.487936     0.0  7.101719
# 1  20230101 020000  55.904335  0.344468     0.0  7.101719
# 2  20230101 030000  57.698057  0.193766     0.0  7.101719
# 3  20230101 040000  55.156951  0.222383     0.0  7.101719
# 4  20230101 050000  56.053812  0.175436     0.0  7.101719

# %%
df.dtypes
# Out:
# Time        object
# Energy     float64
# load       float64
# ESMODE     float64
# TXpower    float64
# dtype: object

# %%
dummies = pd.get_dummies('Time', drop_first = True)

# %%
dummies
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
model = DecisionTreeRegressor()

# %%
y = df.Energy
X = df.drop('Energy', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(X_test, y_test)
# Out:
# 0.7523853381227377

# %%
model.score(X_train, y_train)
# Out:
# 0.9869346565767146

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
model = RandomForestRegressor()

# %%
y = df.Energy
X = df.drop('Energy', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(X_test, y_test)
# Out:
# 0.813151542339708

# %%
model.score(X_train, y_train)
# Out:
# 0.9646648225781203
